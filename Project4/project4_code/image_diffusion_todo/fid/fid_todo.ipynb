# %% [markdown]
# ### TODO:
# Run the code to mesure FID and report it in this notebook, do it for both 0.0 and 7.5 guidance scales, as requested.
# ###

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image

def print_picture(folder_path,data):

    fig, axes = plt.subplots(3, 2, figsize=(8, 12))
    axes = axes.reshape(-1, 2)

    for row_idx, (cat, nums) in enumerate(data.items()):
        for col_idx, n in enumerate(nums):
            ax = axes[row_idx, col_idx]
            img_path = os.path.join(folder_path, f"{n}.png")
            img = Image.open(img_path)
            ax.imshow(img)
            ax.axis('off')
        axes

# %%
######## TODO ########
# Edit and run a command to to measure FID between two directories (7.5 scale)
#1500 pictures in each directory
# !python measure_fid.py ../../data/afhq/eval/ ../../results/samples_080725_7.5_2
folder_path = '../../results/samples_080725_7.5_2'
data_75 = {
    'dog': [72, 346],
    'wild':  [13, 233],
    'cat':  [23, 205]
}
print_picture(folder_path,data_75)
######################
# Out:
# Calculating FID given paths ../../data/afhq/eval/ and ../../results/samples_080725_7.5_2...
# /anaconda/envs/azureml_py38/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /anaconda/envs/azureml_py38/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /anaconda/envs/azureml_py38/lib/python3.10/site-packages/torchvision/models/inception.py:43: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
# ...

# %%
######## TODO ########
# Edit and run a command to to measure FID between two directories (0.0 scale)
#1500 pictures in each directory
# !python measure_fid.py ../../data/afhq/eval/ ../../results/samples_090725_0.0
######################
# Out:
# Calculating FID given paths ../../data/afhq/eval/ and ../../results/samples_090725_0.0...
# /anaconda/envs/azureml_py38/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /anaconda/envs/azureml_py38/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /anaconda/envs/azureml_py38/lib/python3.10/site-packages/torchvision/models/inception.py:43: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
# ...
